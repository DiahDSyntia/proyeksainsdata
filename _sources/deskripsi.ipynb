# %% [markdown]
# # Deskripsi Proses Pipelines

# %% [markdown]
# ### Proses ambil data

# %% [markdown]
# 1.   Pertama, siapkan data yang akan di proses
# 2.   setelah itu masukkan data pada setiap database
# 1.
# 2.   List item
