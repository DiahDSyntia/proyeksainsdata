# %% [markdown]
# # Deskripsi Proses Pipelines

# %% [markdown]
# ### Proses masukkan data ke masing masing database

# %% [markdown]
# 1.   Pertama, siapkan data yang akan di proses
# 2.   Setelah itu masukkan data iris pada setiap database yang diinginkan, seperti mysql, postgre local, postgre elephant, dan sql server
# 1.   Setelah dataset sudah dimasukkan ke database, connect dengan code yang dibuat

# %% [markdown]
# ### Proses orchest io

# %% [markdown]
# Data yang sudah berhasil dimasukkan dalam orchest io adalah postgre elephant
#
#
# Berikut penjelasan singkatnya:
# 1.   Kita harus membuat database dan user di elephant karena di coding akan muncul kebutuhan itu
# 2.   Setelah itu buat new pipline untuk
